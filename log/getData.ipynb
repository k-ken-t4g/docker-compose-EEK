# %%
import datetime
import pandas_datareader.data as web

start = datetime.datetime(2008, 1, 1)
nikkei225 = web.DataReader(["NIKKEI225","DJIA","DEXJPUS"], "fred", start)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-f475d566016f> in <module>()
#       1 import datetime
# ----> 2 import pandas_datareader.data as web
#       3
#       4 start = datetime.datetime(2008, 1, 1)
#       5 nikkei225 = web.DataReader(["NIKKEI225","DJIA","DEXJPUS"], "fred", start)
#
# ~/anaconda/lib/python3.6/site-packages/pandas_datareader/__init__.py in <module>()
#       1 from ._version import get_versions
# ----> 2 from .data import (DataReader, Options, get_components_yahoo,
#       3                    get_dailysummary_iex, get_data_enigma, get_data_famafrench,
#       4                    get_data_fred, get_data_google, get_data_moex,
#       5                    get_data_morningstar, get_data_quandl, get_data_stooq,
#
# ~/anaconda/lib/python3.6/site-packages/pandas_datareader/data.py in <module>()
#      12     ImmediateDeprecationError
# ...

# %%
import pandas_datareader as pdr
pdr.get_data_fred('GS10')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-0a61ade5ae63> in <module>()
# ----> 1 import pandas_datareader as pdr
#       2 pdr.get_data_fred('GS10')
#
# ~/anaconda/lib/python3.6/site-packages/pandas_datareader/__init__.py in <module>()
#       1 from ._version import get_versions
# ----> 2 from .data import (DataReader, Options, get_components_yahoo,
#       3                    get_dailysummary_iex, get_data_enigma, get_data_famafrench,
#       4                    get_data_fred, get_data_google, get_data_moex,
#       5                    get_data_morningstar, get_data_quandl, get_data_stooq,
#
# ~/anaconda/lib/python3.6/site-packages/pandas_datareader/data.py in <module>()
#      12     ImmediateDeprecationError
#      13 from pandas_datareader.famafrench import FamaFrenchReader
# ---> 14 from pandas_datareader.fred import FredReader
# ...

# %%
import pandas as pd

df = pd.read_csv('/Users/KentoK/Downloads/data.csv',encoding="SHIFT-JIS")

# %%
df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ダウンロードした時刻：2018/08/24 13:44:33
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-7e0f2d1207f1> in <module>()
# ----> 1 from pandas_datareader import data, wb
#
# ~/anaconda/lib/python3.6/site-packages/pandas_datareader/__init__.py in <module>()
#       1 from ._version import get_versions
# ----> 2 from .data import (DataReader, Options, get_components_yahoo,
#       3                    get_dailysummary_iex, get_data_enigma, get_data_famafrench,
#       4                    get_data_fred, get_data_google, get_data_moex,
#       5                    get_data_morningstar, get_data_quandl, get_data_stooq,
#
# ~/anaconda/lib/python3.6/site-packages/pandas_datareader/data.py in <module>()
#      12     ImmediateDeprecationError
#      13 from pandas_datareader.famafrench import FamaFrenchReader
# ---> 14 from pandas_datareader.fred import FredReader
# ...
